# %%
# %sh get_data.sh
# Out:
# UsageError: Line magic function `%sh` not found (But cell magic `%%sh` exists, did you mean that instead?).

# %%
# !conda install posix
# Out:
# m2-gcc-libs-5.3.0    | 1021 KB   | ######7    |  67%
# m2-gcc-libs-5.3.0    | 1021 KB   | #######6   |  77%
# m2-gcc-libs-5.3.0    | 1021 KB   | ########6  |  86%
# m2-gcc-libs-5.3.0    | 1021 KB   | #########5 |  96%
# m2-gcc-libs-5.3.0    | 1021 KB   | ########## | 100%
#
# m2-zlib-1.2.8        | 51 KB     |            |   0%
# m2-zlib-1.2.8        | 51 KB     | ###1       |  32%
# m2-zlib-1.2.8        | 51 KB     | ########## | 100%
#
# m2-unzip-6.0         | 132 KB    |            |   0%
# m2-unzip-6.0         | 132 KB    | #2         |  12%
# m2-unzip-6.0         | 132 KB    | ######     |  60%
# m2-unzip-6.0         | 132 KB    | ########## | 100%
#
# m2-grep-2.22         | 259 KB    |            |   0%
# m2-grep-2.22         | 259 KB    | 6          |   6%
# m2-grep-2.22         | 259 KB    | #####5     |  56%
# m2-grep-2.22         | 259 KB    | #########2 |  93%
# m2-grep-2.22         | 259 KB    | ########## | 100%
#
# posix-1.0.0          | 2 KB      |            |   0%
# ...
