# %%
# !git clone https://github.com/wenhuchen/GNN-TabFact.git
# !git clone https://github.com/wenhuchen/Table-Fact-Checking.git
# Out:
# Cloning into 'GNN-TabFact'...
# remote: Enumerating objects: 16689, done.
# remote: Counting objects: 100% (16689/16689), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 16689 (delta 16603), reused 16639 (delta 16567), pack-reused 0
# Receiving objects: 100% (16689/16689), 10.73 MiB | 23.57 MiB/s, done.
# Resolving deltas: 100% (16603/16603), done.
# Checking out files: 100% (16588/16588), done.
# Cloning into 'Table-Fact-Checking'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 144673 (delta 95), reused 74 (delta 21), pack-reused 144484
# Receiving objects: 100% (144673/144673), 756.57 MiB | 36.58 MiB/s, done.
# Resolving deltas: 100% (79933/79933), done.
# Checking out files: 100% (16636/16636), done.

# %%
# %cd GNN-TabFact
# Out:
# /content/GNN-TabFact

# %%
# !mkdir models

# %%
# %cd models
# Out:
# /content/models

# %%
# !wget https://gnntabfact.s3-us-west-2.amazonaws.com/gnn_fp16_numeric.zip
# !unzip gnn_fp16_numeric.zip
# Out:
# --2020-10-10 16:31:09--  https://gnntabfact.s3-us-west-2.amazonaws.com/gnn_fp16_numeric.zip
# Resolving gnntabfact.s3-us-west-2.amazonaws.com (gnntabfact.s3-us-west-2.amazonaws.com)... 52.218.244.25
# Connecting to gnntabfact.s3-us-west-2.amazonaws.com (gnntabfact.s3-us-west-2.amazonaws.com)|52.218.244.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 708697699 (676M) [application/zip]
# Saving to: ‘gnn_fp16_numeric.zip’
#
# gnn_fp16_numeric.zi 100%[===================>] 675.87M  36.6MB/s    in 19s
#
# 2020-10-10 16:31:29 (35.1 MB/s) - ‘gnn_fp16_numeric.zip’ saved [708697699/708697699]
#
# Archive:  gnn_fp16_numeric.zip
#    creating: gnn_fp16_numeric/
#   inflating: gnn_fp16_numeric/.DS_Store
#   inflating: gnn_fp16_numeric/config.txt
#   inflating: gnn_fp16_numeric/.history
#   inflating: gnn_fp16_numeric/model_ep4.pt
#    creating: gnn_fp16_numeric/events/
#   inflating: gnn_fp16_numeric/events/events.out.tfevents.1578110545.edward.cs.ucsb.edu

# %%
# %cd GNN-TabFact
# Out:
# /content/GNN-TabFact

# %%
# !CUDA_VISIBLE_DEVICES=0 python gnn.py --model bert-base-multilingual-uncased --do_train --encoding gnn --output_dir models/gnn_fp16_numeric_test --attention cross --lr_default 5e-6
# Out:
# Streaming output truncated to the last 5000 lines.
# ###########################
#
# Evaluation:   8% 139/1695 [00:29<05:21,  4.84it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   8% 141/1695 [00:29<04:52,  5.32it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   8% 142/1695 [00:29<06:04,  4.26it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   8% 143/1695 [00:29<05:30,  4.70it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   8% 144/1695 [00:30<04:44,  5.45it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 145/1695 [00:30<06:05,  4.24it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 146/1695 [00:30<05:05,  5.06it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 148/1695 [00:30<04:25,  5.83it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 149/1695 [00:31<05:26,  4.73it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 150/1695 [00:31<05:37,  4.57it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 152/1695 [00:31<05:02,  5.11it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 153/1695 [00:31<05:31,  4.65it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 154/1695 [00:32<05:38,  4.55it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9% 155/1695 [00:32<07:08,  3.59it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:   9%
/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  83% 1408/1695 [04:41<00:58,  4.92it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  83% 1410/1695 [04:41<00:49,  5.75it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  83% 1411/1695 [04:41<00:43,  6.53it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  83% 1412/1695 [04:41<00:41,  6.81it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  83% 1413/1695 [04:41<00:45,  6.23it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  83% 1414/1695 [04:41<00:40,  6.91it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  83% 1415/1695 [04:42<00:44,  6.30it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1416/1695 [04:42<00:58,  4.74it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1417/1695 [04:42<01:09,  3.98it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1418/1695 [04:42<01:08,  4.05it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1419/1695 [04:43<01:09,  3.95it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1420/1695 [04:43<01:22,  3.34it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1422/1695 [04:43<01:03,  4.27it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1423/1695 [04:43<00:55,  4.94it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1425/1695 [04:44<00:46,  5.87it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1426/1695 [04:44<00:48,  5.57it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1427/1695 [04:44<00:53,  5.00it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1428/1695 [04:44<01:03,  4.18it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1429/1695 [04:45<01:15,  3.54it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1431/1695 [04:45<00:58,  4.54it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  84% 1432/1695 [04:45<01:01,  4.25it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1433/1695 [04:45<00:52,  5.04it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1434/1695 [04:45<00:45,  5.79it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1436/1695 [04:46<00:48,  5.31it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1437/1695 [04:46<00:56,  4.55it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1438/1695 [04:46<00:58,  4.42it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1439/1695 [04:47<00:57,  4.44it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1440/1695 [04:47<01:14,  3.43it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1442/1695 [04:47<00:59,  4.25it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1443/1695 [04:48<01:03,  3.95it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1444/1695 [04:48<00:58,  4.31it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1446/1695 [04:48<00:46,  5.38it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1447/1695 [04:48<00:51,  4.82it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  85% 1449/1695 [04:48<00:46,  5.32it/s]###########################
# <class 'torch.Tensor'>
# ###########################
# ###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  86% 1451/1695 [04:49<00:40,  6.06it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  86% 1452/1695 [04:49<00:58,  4.18it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  86% 1453/1695 [04:49<00:52,  4.65it/s]###########################
# <class 'torch.Tensor'>
# ###########################
#
# Evaluation:  86% 1454/1695 [04:49<00:45,  5.35it/s]###########################
# <class 'torch.Tensor'>
# ###########################

# %%
# !pip install allennlp
# Out:
# Requirement already satisfied: allennlp in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: spacy<2.4,>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from allennlp) (2.2.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from allennlp) (2.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from allennlp) (1.4.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from allennlp) (3.6.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from allennlp) (3.2.5)
# Requirement already satisfied: requests>=2.18 in /usr/local/lib/python3.6/dist-packages (from allennlp) (2.23.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from allennlp) (0.22.2.post1)
# Requirement already satisfied: tqdm>=4.19 in /usr/local/lib/python3.6/dist-packages (from allennlp) (4.41.1)
# Requirement already satisfied: overrides==3.1.0 in /usr/local/lib/python3.6/dist-packages (from allennlp) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from allennlp) (1.18.5)
# Requirement already satisfied: filelock<3.1,>=3.0 in /usr/local/lib/python3.6/dist-packages (from allennlp) (3.0.12)
# Requirement already satisfied: tensorboardX>=1.2 in /usr/local/lib/python3.6/dist-packages (from allennlp) (1.8)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.6/dist-packages (from allennlp) (1.4.1)
# Requirement already satisfied: transformers<3.1,>=3.0 in /usr/local/lib/python3.6/dist-packages (from allennlp) (3.0.2)
# Requirement already satisfied: jsonnet>=0.10.0; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from allennlp) (0.16.0)
# Requirement already satisfied: torch<1.7.0,>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from allennlp) (1.6.0+cu101)
# Requirement already satisfied: boto3<2.0,>=1.14 in /usr/local/lib/python3.6/dist-packages (from allennlp) (1.15.16)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from allennlp) (0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (50.3.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (3.0.2)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (0.8.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4,>=2.1.0->allennlp) (2.0.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->allennlp) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->allennlp) (20.2.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->allennlp) (1.9.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->allennlp) (1.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->allennlp) (8.5.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->allennlp) (0.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->allennlp) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->allennlp) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->allennlp) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->allennlp) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->allennlp) (0.16.0)
# Requirement already satisfied: protobuf>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX>=1.2->allennlp) (3.12.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.6/dist-packages (from jsonpickle->allennlp) (2.0.0)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in /usr/local/lib/python3.6/dist-packages (from transformers<3.1,>=3.0->allennlp) (0.8.1rc1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers<3.1,>=3.0->allennlp) (20.4)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers<3.1,>=3.0->allennlp) (0.0.43)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.6/dist-packages (from transformers<3.1,>=3.0->allennlp) (0.1.91)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers<3.1,>=3.0->allennlp) (2019.12.20)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch<1.7.0,>=1.6.0->allennlp) (0.16.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3<2.0,>=1.14->allennlp) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3<2.0,>=1.14->allennlp) (0.10.0)
# Requirement already satisfied: botocore<1.19.0,>=1.18.16 in /usr/local/lib/python3.6/dist-packages (from boto3<2.0,>=1.14->allennlp) (1.18.16)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata->jsonpickle->allennlp) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers<3.1,>=3.0->allennlp) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers<3.1,>=3.0->allennlp) (7.1.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.19.0,>=1.18.16->boto3<2.0,>=1.14->allennlp) (2.8.1)

# %%
# Out:
# Collecting folium==0.2.1
#   Downloading https://files.pythonhosted.org/packages/72/dd/75ced7437bfa7cb9a88b96ee0177953062803c3b4cde411a97d98c35adaf/folium-0.2.1.tar.gz (69kB)
#      |████████████████████████████████| 71kB 5.2MB/s
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from folium==0.2.1) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2->folium==0.2.1) (1.1.1)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.2.1-cp36-none-any.whl size=79980 sha256=ab953506b79ccf271918a1461d6000002a02c51da5d42c4c432f8cb0c8e12723
#   Stored in directory: /root/.cache/pip/wheels/b8/09/f0/52d2ef419c2aaf4fb149f92a33e0008bdce7ae816f0dd8f0c5
# Successfully built folium
# Installing collected packages: folium
#   Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# Successfully installed folium-0.2.1

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (3.0.2)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8.1rc1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.1.91)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.6.20)

# %%
# !pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.32.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (3.2.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (50.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.15.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (0.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.0.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (3.12.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.7.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.18.5)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard) (0.35.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (2.23.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard) (2.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard) (3.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.1.0)

# %%
# !pip install --upgrade torch
# Out:
# Requirement already up-to-date: torch in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)

# %%
# !pip uninstall protobuf
# !pip install --no-binary=protobuf protobuf
# Out:
# Uninstalling protobuf-3.12.4:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/google/protobuf/*
#     /usr/local/lib/python3.6/dist-packages/protobuf-3.12.4-py3.6-nspkg.pth
#     /usr/local/lib/python3.6/dist-packages/protobuf-3.12.4.dist-info/*
# Proceed (y/n)? ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/cli/base_command.py", line 153, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/commands/uninstall.py", line 79, in run
#     auto_confirm=options.yes, verbose=self.verbosity > 0,
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/req/req_install.py", line 755, in uninstall
#     uninstalled_pathset.remove(auto_confirm, verbose)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/req/req_uninstall.py", line 388, in remove
#     if auto_confirm or self._allowed_to_proceed(verbose):
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/req/req_uninstall.py", line 431, in _allowed_to_proceed
#     return ask('Proceed (y/n)? ', ('y', 'n')) == 'y'
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/utils/misc.py", line 245, in ask
#     response = input(message)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/main.py", line 47, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/cli/base_command.py", line 103, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/cli/base_command.py", line 183, in _main
#     logger.debug('Exception information:', exc_info=True)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1296, in debug
#     self._log(DEBUG, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/usr/lib/python3.6/logging/handlers.py", line 73, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1072, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/utils/logging.py", line 151, in format
#     formatted = super(IndentingFormatter, self).format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 585, in format
#     record.exc_text = self.formatException(record.exc_info)
#   File "/usr/lib/python3.6/logging/__init__.py", line 535, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/usr/lib/python3.6/traceback.py", line 104, in print_exception
#     type(value), value, tb, limit=limit).format(chain=chain):
#   File "/usr/lib/python3.6/traceback.py", line 509, in __init__
#     capture_locals=capture_locals)
#   File "/usr/lib/python3.6/traceback.py", line 364, in extract
#     f.line
#   File "/usr/lib/python3.6/traceback.py", line 286, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "/usr/lib/python3.6/linecache.py", line 16, in getline
#     lines = getlines(filename, module_globals)
#   File "/usr/lib/python3.6/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/usr/lib/python3.6/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/usr/lib/python3.6/tokenize.py", line 454, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/usr/lib/python3.6/tokenize.py", line 423, in detect_encoding
#     first = read_or_stop()
#   File "/usr/lib/python3.6/tokenize.py", line 381, in read_or_stop
#     return readline()
# KeyboardInterrupt
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (3.12.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf) (50.3.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf) (1.15.0)

# %%
# !pip install tensorboard==1.14.0
# Out:
# Collecting tensorboard==1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 2.8MB/s
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (3.2.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (0.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (1.15.0)
# Requirement already satisfied: grpcio>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (1.32.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (1.18.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (50.3.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (0.35.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (3.12.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard==1.14.0) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard==1.14.0) (3.2.0)
# ERROR: tensorflow 2.3.0 has requirement tensorboard<3,>=2.3.0, but you'll have tensorboard 1.14.0 which is incompatible.
# Installing collected packages: tensorboard
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
# Successfully installed tensorboard-1.14.0

# %%
# !pip install tensorboardX==1.8
# Out:
# Collecting tensorboardX==1.8
#   Downloading https://files.pythonhosted.org/packages/c3/12/dcaf67e1312475b26db9e45e7bb6f32b540671a9ee120b3a72d9e09bc517/tensorboardX-1.8-py2.py3-none-any.whl (216kB)
#      |████████████████████████████████| 225kB 2.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX==1.8) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX==1.8) (1.15.0)
# Requirement already satisfied: protobuf>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX==1.8) (3.12.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.2.0->tensorboardX==1.8) (50.3.0)
# Installing collected packages: tensorboardX
#   Found existing installation: tensorboardX 2.1
#     Uninstalling tensorboardX-2.1:
#       Successfully uninstalled tensorboardX-2.1
# Successfully installed tensorboardX-1.8

# %%
# Out:
# Cloning into 'Table-Fact-Checking'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 144673 (delta 95), reused 74 (delta 21), pack-reused 144484
# Receiving objects: 100% (144673/144673), 756.57 MiB | 18.86 MiB/s, done.
# Resolving deltas: 100% (79933/79933), done.
# Checking out files: 100% (16636/16636), done.
